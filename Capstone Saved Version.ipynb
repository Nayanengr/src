# %%
import pandas as pd
import numpy as np

# %%
df_new =pd.read_csv('Capstone_modified.csv')
support_data = pd.read_csv('Support_harkirat.csv')
cosine_sim = np.load('cosing_harkirat.npy')
indices = pd.read_csv('indices_harkirat.csv',names = ['name','indices'])

# %%
indices = pd.Series(indices.index, index=indices['name']).drop_duplicates()

# %%
indices
# Out:
# name
# Razer BlackWidow Chroma Keyboard        0
# AVA-VIV Blouse                          1
# Leather Horse Statues                   2
# 24K GOLD plated rose                    3
# Bundled items requested for Ruie        4
#                                     ...
# Tarte Park Ave Princess             23603
# Air jordan Low Top 6                23604
# Free People moonshine sweater       23605
# Nose piercing                       23606
# Lularoe OS leggings sunglasses      23607
# Length: 23608, dtype: int64

# %%
    def get_comp(value):
        return support_data[(support_data['name_x'] == value) | (support_data['name_y'] == value)].sort_values(by = 'support',ascending = False).head(10)

# %%
get_comp('sweat pants')
# Out:
#      Unnamed: 0                               name_x  \
# 36           36                          sweat pants
# 38           38                          sweat pants
# 39           39  MLB Cincinnati Reds T Shirt Size XL
# 37           37                          sweat pants
# 80           80                  NWOT NIKE TUNIC TOP
# 393         393                   Lulaoe julia stars
# 337         337  VSX the player racerback sports bra
# 306         306                       MTV half shirt
# 262         262                          sweat pants
# 238         238           Rae Dunn Good Morning Bowl
#
#                                  name_y   support  price_x  price_y
# 36   11" Baltic amber teething necklace  0.388889     13.0     20.0
# 38            Soul Calibur II Xbox Game  0.388889     13.0      8.0
# 39                          sweat pants  0.388889     10.0     13.0
# 37               2 Polo Rugby(Wingtips)  0.388889     13.0     20.0
# 80                          sweat pants  0.333333     24.0     13.0
# 393                         sweat pants  0.333333     20.0     13.0
# 337                         sweat pants  0.333333     15.0     13.0
# 306                         sweat pants  0.333333      7.0     13.0
# 262  iPhone 6/6S, 7 360 Full Armor Case  0.333333     13.0      8.0
# 238                         sweat pants  0.333333     18.0     13.0

# %%
cosine_sim
# Out:
# array([[1.        , 0.        , 0.        , ..., 0.03262159, 0.02605355,
#         0.        ],
#        [0.        , 1.        , 0.        , ..., 0.        , 0.03423422,
#         0.        ],
#        [0.        , 0.        , 1.        , ..., 0.04629485, 0.02844579,
#         0.0885656 ],
#        ...,
#        [0.03262159, 0.        , 0.04629485, ..., 1.        , 0.        ,
#         0.06598005],
#        [0.02605355, 0.03423422, 0.02844579, ..., 0.        , 1.        ,
#         0.02657415],
#        [0.        , 0.        , 0.0885656 , ..., 0.06598005, 0.02657415,
#         1.        ]])

# %%
def get_subsitute(name, cosine_sim=cosine_sim):
    # Get the index of the item that matches the title
    idx = indices[name]
    print(idx)

    # Get the pairwsie similarity scores of all items with that items
    sim_scores = list(enumerate(cosine_sim[idx]))
    
    # Sort the items based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    
    # Get the scores of the 10 most similar items
    sim_scores = sim_scores[1:11]
    
    # Get the items indices
    item_indices = [i[0] for i in sim_scores]
    
    # Return the top 10 most similar items
    #return df_new['name'].iloc[item_indices]
    return df_new.iloc[item_indices].sort_values(by = 'price')

# %%
get_subsitute ("Girls Nike Pro shorts")
# Out:
# 7
#        Unnamed: 0                                  name  \
# 6               6  Girls cheer and tumbling bundle of 7
# 19436       19436                          Carter's PJs
# 14965       14965        Girls Polo Ralph Lauren Shorts
# 13500       13500                    Bundle for Shawnee
# 10285       10285                Kids Adidas jacket nwt
# 5723         5723                  American Eagle jeans
# 22879       22879    Gray and Black girls boots size 10
# 17643       17643                           New Bundle!
# 14077       14077                   Girls miss me jeans
# 2207         2207  Victoria's Secret PINK Lot Sz medium
#
#                                         item_description  price
# 6      You get three pairs of Sophie cheer shorts siz...    6.0
# 19436  Girls Carter's PJS Size 5T Pink & orange / blu...   10.0
# 14965                       Size 10 in Girls! Brand New.   14.0
# 13500                                     5 shirts total   16.0
# 10285                                       Girls size 5   17.0
# 5723                                       Size 12 short   17.0
# 22879                                   Size 10 girls :)   20.0
# 17643                                   4 shorts Size 38   20.0
# 14077                                 Girls size 12 new!   32.0
# 2207   This is for two bundles plus two mint green sh...   75.0

# %%
# initialize gui
from tkinter import *
from pandastable import Table
#insert widgets to process input
class MyWindow:
    def __init__(self, win):
        lbl1=Label(win, text='Item')
        lbl2=Label(win, text='Result')
        t1=Entry(bd=3)
        t2=Entry()
        btn1=Button(win, text='Complement')
        btn2=Button(win, text='Substitute')
        lbl1.place(x=100, y=50)
        t1.place(x=300, y=50)
        #define user inputs after the command function
        b1=Button(win, text='Complement',command=get_comp('sweat pants'))
        b2=Button(win, text='Substitute',command=get_subsitute('American Eagle jeans'))
        #bind functions here
        b1.bind('<Button1>')
        b2.bind('<Button1>')
        b1.place(x=100, y=150)
        b2.place(x=300, y=150)
        lbl2.place(x=100, y=200)
        t2.place(x=300, y=200)
        #define backend after this line
window=Tk()
mywin=MyWindow(window)
window.title('Pricing Engine')
window.geometry("400x300+10+10")
window.mainloop()
# Out:
# American Eagle jeans     5723
# American Eagle jeans    12055
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-aec6f6b684b7> in <module>
#      25         #define backend after this line
#      26 window=Tk()
# ---> 27 mywin=MyWindow(window)
#      28 window.title('Pricing Engine')
#      29 window.geometry("400x300+10+10")
#
# <ipython-input-11-aec6f6b684b7> in __init__(self, win)
#      15         #define user inputs after the command function
#      16         b1=Button(win, text='Complement',command=get_comp('sweat pants'))
# ---> 17         b2=Button(win, text='Substitute',command=get_subsitute('American Eagle jeans'))
#      18         #bind functions here
#      19         b1.bind('<Button1>')
#
# <ipython-input-9-1b5bed425219> in get_subsitute(name, cosine_sim)
#       8
#       9     # Sort the items based on the similarity scores
# ---> 10     sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
#      11
#      12     # Get the scores of the 10 most similar items
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
